# %%
import scanpy as sc
import matplotlib.pyplot as plt

# %%
adata = sc.read('data/sim_anndata_linear_model_5000_cells_2000_genes_4_factors_0_seed_50_percent_act_shuffle.h5ad')

# %%
plt.scatter(adata.obs['steps_1'], adata.obs['steps_2'])
